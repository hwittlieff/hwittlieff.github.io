# %% [markdown]
# # Assignment 11
# Using section 8.1 in Deep Learning with Python as a guide, implement an LSTM text generator. Train the model on the Enron corpus or a text source of your choice. Save the model and generate 20 examples to the results directory of dsc650/assignments/assignment11/.

# %%
# Download and parse the initial text file
from tensorflow import keras
import numpy as np
path = keras.utils.get_file('nietzsche.txt', origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# Corpus length: 600901

# %%
# Vectorizing sequences of characters
maxlen = 60
step = 3
sentences = []
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print('Number of sequences:', len(sentences))

chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=bool)
y = np.zeros((len(sentences), len(chars)), dtype=bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
        y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200281
# Unique characters: 59
# Vectorization...

# %%
# Build the network & compile the model
from keras import layers
model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
optimizer = keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %%
# Define a function to sample the next character given the model's predictions
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# Fir model and generate text
import random
import sys
for epoch in range(1, 6):
    print('epoch', epoch)
    model.fit(x, y, batch_size=128, epochs=1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')
    model.save('results/Epoch '+ str(epoch) + ' model.h5')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        file_name = 'Epoch ' + str(epoch) + ' Temp ' + str(temperature)
        sys.stdout.write(generated_text)
        seed = 'Generated with seed: ' + generated_text
        text_string = generated_text
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            generated_text += next_char
            generated_text = generated_text[1:]
            sys.stdout.write(next_char)
            text_string += next_char
        lines = [seed, text_string]
        with open ('results/' + file_name + '.txt', 'w') as f:
            for line in lines:
                f.write(line)
                f.write('\n')
                f.write('\n')
# Out:
# epoch 1
# 1565/1565 [==============================] - 100s 64ms/step - loss: 1.3314
# --- Generating with seed: "ible
# to determine with certainty which is cause and which is"
# ------ temperature: 0.2
# ible
# to determine with certainty which is cause and which is the same and a morality of the same and an and his conscience of the same the present a south in and man in the most and the problem of the same the same and with the same and action of the conception of the sense of the sense of the same and the same and heart and the heart of a fact, and an and an and an and of the same the higher the same and without something of the fact of the same and the s------ temperature: 0.5
# same and without something of the fact of the same and the sensation of the fact.--the constant say that under health--in order to him who has a consequence-custably to intellectual to man into him that which is in the most sarrifical conduct and heart of a men of the world in fact and an and the subjection of height and master of the old something of the
# spirit to sea                                                                                         ------ temperature: 1.0
#                                                                                           nemitraming that also in this greek pact, and assertion--rate and man. i one rgreseny as should asout higher,
# and wishes of
# the new,"
# the sbecretiyginapses
# are hempled not, virtumant without punished it would possition who scas hardmniture and
# (what besupictasinaguincte of
# schouth vainness of our wait.--they has lay do in voutative, could happenee has
# verduste has xta------ temperature: 1.2
# has lay do in voutative, could happenee has
# verduste has xtappos!, ir own person to obster willing-cannot
# pla: heverave vintement,-orgutise fundiar and express quitur shriven: "find fariloo, no fraund out-own
# usse and glirmant into lapses which serinature honon are tendaments act may protent mest
# and consciends, necloue
# to feelon without up in to se" solans, emotions which he sound could to
# combrow mevatic fundamental keptine shase may sea subtlity"--so thepoch 2
# 1565/1565 [==============================] - 103s 66ms/step - loss: 1.3271
# --- Generating with seed: "the master of his virtues, and of super-abundance of will;
# p"
# ------ temperature: 0.2
# the master of his virtues, and of super-abundance of will;
# perhaps the state of the same and the surpender to the strength of the sense of the same such a souls and the surpender of the same the sense they are standard of the sense of the same taste, the same such a sense of the strength of the present the same the spiritual and the best in the strength of the probable and stoped the sacrifice of the same taken person to the state of the sense of the sense------ temperature: 0.5
# the same taken person to the state of the sense of the sense of the world, and the same and the man is at logicity, the distinction of the best and the emotions of the condition of the time for the epiced without the branding of the basis of the person is not its suffering them with the more standing the habitation of the sense of the able to the sense of the fact is greatest them in his explanation, because a stors of the act to even strength and fear its------ temperature: 1.0
# on, because a stors of the act to even strength and fear itself, and of their, eachion of digness
# physible of its a, to the thinke andes must . it is as others as day harality of a nessation of recide forw memently in opinion indicate the awagnerud
# immense
# no manifellly mypothes to feel justice, of results and even that rerapt out. they. he ise the interestion! in a veless
# who-solation of at the part of the aristom therefore, upperiousness, on a probabice ------ temperature: 1.2
# art of the aristom therefore, upperiousness, on a probabice to
# itstain-touth
# must ever gri, as the questions which doubt of the
# will is ferverract.--herly thererckogius
# the interpreptine (and to indigire's to explines contorsious without
# them our brus." is the gerkad
# mhaseb doubl hates,
# for in -trades, indigner domanimated and delur, sceecy of gets these devindwardedness shrinks "a place trinblef"--this questict. i know every
# romans
# curve (to
# is just more epoch 3
# 1565/1565 [==============================] - 105s 67ms/step - loss: 1.3214
# --- Generating with seed: "re, higher, greater,
# and fundamentally different, which does"
# ------ temperature: 0.2
# re, higher, greater,
# and fundamentally different, which does not the same the moral instincts, the sense of the senses of the morality and superiority and self-destrusting the consideration of the priest the whole of the complete the superficial the personality and senses of the philosophers and significance and the same the sense of the senses and the conception of the philosophers and seriousness of the superficial philosophers and the same the superfici------ temperature: 0.5
# s of the superficial philosophers and the same the superficial and all beauty.--the conditions, which is resistion of the whole arigound a morals in the sense of the truth and deal former and in every neitht the moralistical new the same the transgers the philosophers and the greatest for the promises and society that it seems a hard execual instincts, and considerations of the former and
# experience of the good and deception of the personality to the same ------ temperature: 1.0
# ce of the good and deception of the personality to the same brand
# just to present, and its have organ they so that let us greate-hard and conductial, the last ferthear, fording of whateves not before as those or granthold interptiouss: that is not, horan
# in the
# moralise exsimyss, the terrible--that himself aly
# thought be
# gro, all their steach and avoars, motives, thate of independence hard by plants to a reagent causes. and the contradicted him in the obje------ temperature: 1.2
# ts to a reagent causes. and the contradicted him in the objects and
# approhis;: else, he deemed any perhapes, it is orogliurs of,
# ce cultion) and merrow as ily
# have the rest made
# one that
# is well he stappicou ponsible
# ilal"junte" during afeciour, "the nest caments;
# the speauin
# iacious, to do heaves him,verlugabled, however, which as
# moyt often this forgarce trided ov"
# prulosy as errouth)
# ellogy
#
# untrit-commechfuls, when he sy weach ehrorgest the sufpent outepoch 4
# 1565/1565 [==============================] - 102s 65ms/step - loss: 1.3196
# --- Generating with seed: "ion of the
# command. that which is termed "freedom of the wil"
# ------ temperature: 0.2
# ion of the
# command. that which is termed "freedom of the will, the senses of the personality of the part of the spirit of the same the fact the german thing of the world that is the descent to the same the same the art of the senses of the end of the support to the destroys and the end of the sense of the senses of the problem of the same the same the same and the senses of the most conditions of the senses of the same the spirit of the same and the popula------ temperature: 0.5
# the senses of the same the spirit of the same and the popular in an instincts in himself and not one that us a man wainthy, is i are an all the politice, to what is woman, and suspicion and state of the senses in the foreign of the really that is the satisfied, in the foreurring. the individual for the more striggle of the personality of the personal philosophical destroys to great the reality of the tempo of the man is freedom that the conscience of the e------ temperature: 1.0
# the tempo of the man is freedom that the conscience of the excessed with even when the supportaw in which has a destrogal iedwinesss of responsibility with thitherthened with denarganting a higher, in the maids perviman will.
# the general does not sylence asholder ashare--for ye thought
# of the german condimous, thought has prited from him, here truth there are feelings-tantany had moralityion and survives.
#
# 148. enemance asken, and an taste. but we danger.
# ------ temperature: 1.2
# urvives.
#
# 148. enemance asken, and an taste. but we danger.
#
# eghon is chy qualities. in thirst opposition as bestricate
# precisely which has always ambiging. even can truth sympathy to his alse, religiously dombets there will asmelt truth of been sociely "important.
#
# 1everthear: as perbacc
# is beings." ha" only the exastebs to conducantsumom.
#
# 144. which has only that ghelys: hetheribudent. i"(unan
# zedancy thre "bew of questioned avoises (which devolding ionepoch 5
# 1565/1565 [==============================] - 101s 65ms/step - loss: 1.3161
# --- Generating with seed: "on. such pains are birth pains. the butterfly
# insists upon b"
# ------ temperature: 0.2
# on. such pains are birth pains. the butterfly
# insists upon belief this spiritual and things and the latter of the sacrifice the same things and superiority of the present in the supersicy of the superstition of the desires to the sense of the more society to the strength of the consequently of the most things of the sense of the philosophers in the sense of the same and some things to the sense of the loves of the results of the spirit of the sense of the ------ temperature: 0.5
#  the loves of the results of the spirit of the sense of the more sand, all this priestly in the results of the results of the good in the fact there
# is to present the lost and interesting things as because they could things to individual and happenest for the remantions the great one which are desire to the instincts in the result of the desire to the great we means of the future. they all those philosopher to the world to the superiority to remant to the ------ temperature: 1.0
# hilosopher to the world to the superiority to remant to the destrusts say, explanation of the
# poilsily "prieful and sun
# are there
#      throw of the naturales of an (har bit civilizations
# the organ and thinker unall for which the present shane ma sought
# the
# anti" his yitful and something dron is in feelings thought, all that may be lapses as the call it words on the sage resclies. becomes the inby the value (or even svois this one was operate
# to
# my wanfer t------ temperature: 1.2
# the value (or even svois this one was operate
# to
# my wanfer to have minssement are stepds outwilt of memner souls give.
#
# 2iceece app a upxky and acflises, but those pleases designodwised non.
#     new wast insuhate--men there stell originus to the question. distunigible singitly, one elsing so by ivow finall to
# mecare of this "zevereffections-.=--this controled to
# preded thised manifestat
# and to the tencies mental path--civery if, not (order of eagh, to the
